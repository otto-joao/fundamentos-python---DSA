# %% [markdown]
# lógica de programação, variáveis, tipos e estruturas de dados parte 1

# %%
nome = "ottinprivkk"
int = 7
float = 0.2
bool = True

# %%
print(type(nome))
print(type(int))
print(type(float))  
print(type(bool))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
